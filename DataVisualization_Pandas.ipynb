# %%
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv('data/csv_data_1.csv')
dt
# Out:
#     id             name  price  sales          brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0        MusleUp

# %%
dt.fillna(0, inplace=True)

# %%
dt.plot()
# Out:
# <AxesSubplot:>

# %%
dt['sales'].plot()
# Out:
# <AxesSubplot:>

# %%
dt['sales'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
dt['sales'].plot.barh()
# Out:
# <AxesSubplot:>

# %%
dt.drop(columns=['id'],inplace=True)

# %%
dt.plot.bar()
# Out:
# <AxesSubplot:>

# %%
dt.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
dt.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
dt.plot.area()
# Out:
# <AxesSubplot:>

# %%
dt.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
dt.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dt['sales'].mean()
# Out:
# 83.125

# %%
dt['sales'].sum()
# Out:
# 665.0

# %%
analytics = pd.DataFrame({'Actual Sales': dt['sales'],
                          'Total Sales' : [665,665,665,665,665,665,665,665],
                          'Average Sales': [83,83,83,83,83,83,83,83]})
                        
                         
                         #index = [1])
analytics.plot.bar()
# Out:
# <AxesSubplot:>
